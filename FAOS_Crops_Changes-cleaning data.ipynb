# %%
import time 
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./data/FAOSTAT_data.csv')
df
# Out:
#        Domain Code Domain  Area Code         Area  Element Code     Element  \
# 0               QC  Crops          2  Afghanistan          5510  Production
# 1               QC  Crops          2  Afghanistan          5510  Production
# 2               QC  Crops          2  Afghanistan          5510  Production
# 3               QC  Crops          2  Afghanistan          5510  Production
# 4               QC  Crops          2  Afghanistan          5510  Production
# ...            ...    ...        ...          ...           ...         ...
# 167939          QC  Crops        181     Zimbabwe          5510  Production
# 167940          QC  Crops        181     Zimbabwe          5510  Production
# 167941          QC  Crops        181     Zimbabwe          5510  Production
# 167942          QC  Crops        181     Zimbabwe          5510  Production
# 167943          QC  Crops        181     Zimbabwe          5510  Production
#
# ...

# %%
df.describe(include='all')
# Out:
#        Domain Code  Domain      Area Code    Area  Element Code     Element  \
# count       167944  167944  167944.000000  167944      167944.0      167944
# unique           1       1            NaN     211           NaN           1
# top             QC   Crops            NaN   China           NaN  Production
# freq        167944  167944            NaN    2137           NaN      167944
# mean           NaN     NaN     127.889040     NaN        5510.0         NaN
# std            NaN     NaN      77.371557     NaN           0.0         NaN
# min            NaN     NaN       1.000000     NaN        5510.0         NaN
# 25%            NaN     NaN      59.000000     NaN        5510.0         NaN
# 50%            NaN     NaN     121.000000     NaN        5510.0         NaN
# 75%            NaN     NaN     191.000000     NaN        5510.0         NaN
# max            NaN     NaN     351.000000     NaN        5510.0         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167944 entries, 0 to 167943
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       167944 non-null  object
#  1   Domain            167944 non-null  object
#  2   Area Code         167944 non-null  int64
#  3   Area              167944 non-null  object
#  4   Element Code      167944 non-null  int64
#  5   Element           167944 non-null  object
#  6   Item Code         167944 non-null  int64
#  7   Item              167944 non-null  object
#  8   Year Code         167944 non-null  int64
#  9   Year              167944 non-null  int64
#  10  Unit              167944 non-null  object
#  11  Value             154810 non-null  float64
#  12  Flag              61941 non-null   object
#  13  Flag Description  167944 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 17.9+ MB

# %% [markdown]
# *We found that in 'Flag' and 'Value' columns there are missing values*
#
# Removing the 'Flag' column from the data set to get a cleaner data:

# %%
df_copy=df.copy()
df_copy=df_copy.drop(columns='Flag')
df_copy
# Out:
#        Domain Code Domain  Area Code         Area  Element Code     Element  \
# 0               QC  Crops          2  Afghanistan          5510  Production
# 1               QC  Crops          2  Afghanistan          5510  Production
# 2               QC  Crops          2  Afghanistan          5510  Production
# 3               QC  Crops          2  Afghanistan          5510  Production
# 4               QC  Crops          2  Afghanistan          5510  Production
# ...            ...    ...        ...          ...           ...         ...
# 167939          QC  Crops        181     Zimbabwe          5510  Production
# 167940          QC  Crops        181     Zimbabwe          5510  Production
# 167941          QC  Crops        181     Zimbabwe          5510  Production
# 167942          QC  Crops        181     Zimbabwe          5510  Production
# 167943          QC  Crops        181     Zimbabwe          5510  Production
#
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167944 entries, 0 to 167943
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       167944 non-null  object
#  1   Domain            167944 non-null  object
#  2   Area Code         167944 non-null  int64
#  3   Area              167944 non-null  object
#  4   Element Code      167944 non-null  int64
#  5   Element           167944 non-null  object
#  6   Item Code         167944 non-null  int64
#  7   Item              167944 non-null  object
#  8   Year Code         167944 non-null  int64
#  9   Year              167944 non-null  int64
#  10  Unit              167944 non-null  object
#  11  Value             154810 non-null  float64
#  12  Flag Description  167944 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 16.7+ MB

# %% [markdown]
# Removing the missing Values from the data set to get a cleaner data

# %%
df_cleaned = df_copy.copy()

for row in df_cleaned :
    df_cleaned = df_cleaned.dropna( axis=0, how='any', subset=[row])
    
df_cleaned
# Out:
#        Domain Code Domain  Area Code         Area  Element Code     Element  \
# 0               QC  Crops          2  Afghanistan          5510  Production
# 1               QC  Crops          2  Afghanistan          5510  Production
# 2               QC  Crops          2  Afghanistan          5510  Production
# 3               QC  Crops          2  Afghanistan          5510  Production
# 4               QC  Crops          2  Afghanistan          5510  Production
# ...            ...    ...        ...          ...           ...         ...
# 167939          QC  Crops        181     Zimbabwe          5510  Production
# 167940          QC  Crops        181     Zimbabwe          5510  Production
# 167941          QC  Crops        181     Zimbabwe          5510  Production
# 167942          QC  Crops        181     Zimbabwe          5510  Production
# 167943          QC  Crops        181     Zimbabwe          5510  Production
#
# ...

# %% [markdown]
# Checking the data for more missing valuse

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154810 entries, 0 to 167943
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       154810 non-null  object
#  1   Domain            154810 non-null  object
#  2   Area Code         154810 non-null  int64
#  3   Area              154810 non-null  object
#  4   Element Code      154810 non-null  int64
#  5   Element           154810 non-null  object
#  6   Item Code         154810 non-null  int64
#  7   Item              154810 non-null  object
#  8   Year Code         154810 non-null  int64
#  9   Year              154810 non-null  int64
#  10  Unit              154810 non-null  object
#  11  Value             154810 non-null  float64
#  12  Flag Description  154810 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 16.5+ MB

# %% [markdown]
# *The data is clean and have more then 50,000 values. we will save it in a new csv file*

# %%
df_cleaned.to_csv("data/FAOSTAT_cleaned_data.csv", index=False)
