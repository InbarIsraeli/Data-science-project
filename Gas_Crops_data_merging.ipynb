# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
# import plotly.graph_objects as go
# import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import time 
import os
# %matplotlib inline

# %%
df_crops = pd.read_csv('./data/FAOSTAT_cleaned_data.csv')
df_crops
# Out:
#        Domain Code Domain  Area Code         Area  Element Code     Element  \
# 0               QC  Crops          2  Afghanistan          5510  Production
# 1               QC  Crops          2  Afghanistan          5510  Production
# 2               QC  Crops          2  Afghanistan          5510  Production
# 3               QC  Crops          2  Afghanistan          5510  Production
# 4               QC  Crops          2  Afghanistan          5510  Production
# ...            ...    ...        ...          ...           ...         ...
# 154805          QC  Crops        181     Zimbabwe          5510  Production
# 154806          QC  Crops        181     Zimbabwe          5510  Production
# 154807          QC  Crops        181     Zimbabwe          5510  Production
# 154808          QC  Crops        181     Zimbabwe          5510  Production
# 154809          QC  Crops        181     Zimbabwe          5510  Production
#
# ...

# %%
df_gas = pd.read_csv('./data/greenhouse gas.csv')
df_gas
# Out:
#     year  CO2_levels  N2O_levels  CH4_levels
# 0   1984      0.3443       303.9        1654
# 1   1985      0.3458       304.5        1666
# 2   1986      0.3472       305.3        1679
# 3   1987      0.3490       305.9        1691
# 4   1988      0.3514       306.7        1703
# 5   1989      0.3530       307.6        1714
# 6   1990      0.3542       308.6        1724
# 7   1991      0.3555       309.3        1735
# 8   1992      0.3562       309.9        1743
# 9   1993      0.3570       310.1        1746
# 10  1994      0.3586       310.7        1752
# 11  1995      0.3604       311.4        1759
# 12  1996      0.3621       312.0        1761
# 13  1997      0.3633       312.9        1765
# 14  1998      0.3660       313.7        1774
# 15  1999      0.3680       314.6        1782
# 16  2000      0.3695       315.7        1783
# 17  2001      0.3710       316.4        1782
# 18  2002      0.3729       317.1        1783
# 19  2003      0.3753       317.7        1787
# ...

# %%
df_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        36 non-null     int64
#  1   CO2_levels  36 non-null     float64
#  2   N2O_levels  36 non-null     float64
#  3   CH4_levels  36 non-null     int64
# dtypes: float64(2), int64(2)
# memory usage: 1.2 KB

# %%
year = [1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983]
CO2_levels = []
N2O_levels = []
CH4_levels = []

for i in year:
    CO2_levels.append('no rec')
    N2O_levels.append('no rec')
    CH4_levels.append('no rec')

df_gas2 = pd.DataFrame({"year":year,"CO2_levels":CO2_levels,"N2O_levels":N2O_levels,"CH4_levels":CH4_levels}) 
df_gas2 = pd.concat([df_gas2, df_gas], ignore_index=True)
df_gas2
# Out:
#     year CO2_levels N2O_levels CH4_levels
# 0   1961     no rec     no rec     no rec
# 1   1962     no rec     no rec     no rec
# 2   1963     no rec     no rec     no rec
# 3   1964     no rec     no rec     no rec
# 4   1965     no rec     no rec     no rec
# 5   1966     no rec     no rec     no rec
# 6   1967     no rec     no rec     no rec
# 7   1968     no rec     no rec     no rec
# 8   1969     no rec     no rec     no rec
# 9   1970     no rec     no rec     no rec
# 10  1971     no rec     no rec     no rec
# 11  1972     no rec     no rec     no rec
# 12  1973     no rec     no rec     no rec
# 13  1974     no rec     no rec     no rec
# 14  1975     no rec     no rec     no rec
# 15  1976     no rec     no rec     no rec
# 16  1977     no rec     no rec     no rec
# 17  1978     no rec     no rec     no rec
# 18  1979     no rec     no rec     no rec
# 19  1980     no rec     no rec     no rec
# 20  1981     no rec     no rec     no rec
# ...

# %%
df_crops.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value',
#        'Flag Description'],
#       dtype='object')

# %%
df_gas_crops = df_crops.copy()
df_gas_crops["CO2_levels"]=0
df_gas_crops["N2O_levels"]=0
df_gas_crops["CH4_levels"]=0
df_gas_crops = df_gas_crops.drop(['Domain Code','Year Code','Element Code'],axis=1)
df_gas_crops
# Out:
#        Domain  Area Code         Area     Element  Item Code    Item  Year  \
# 0       Crops          2  Afghanistan  Production        515  Apples  1961
# 1       Crops          2  Afghanistan  Production        515  Apples  1962
# 2       Crops          2  Afghanistan  Production        515  Apples  1963
# 3       Crops          2  Afghanistan  Production        515  Apples  1964
# 4       Crops          2  Afghanistan  Production        515  Apples  1965
# ...       ...        ...          ...         ...        ...     ...   ...
# 154805  Crops        181     Zimbabwe  Production         15   Wheat  2015
# 154806  Crops        181     Zimbabwe  Production         15   Wheat  2016
# 154807  Crops        181     Zimbabwe  Production         15   Wheat  2017
# 154808  Crops        181     Zimbabwe  Production         15   Wheat  2018
# 154809  Crops        181     Zimbabwe  Production         15   Wheat  2019
#
# ...

# %%
#df_gas2
# df_gas_crops
for i, valA in enumerate(df_gas_crops['Year']):
#     print(valA)
    for j, valB in enumerate(df_gas2['year']):
        if valA == valB:    
#             print(valB)
#             print(j)
#             print(df_gas2['CO2_levels'][j], df_gas2['N2O_levels'][j],df_gas2['CH4_levels'][j])
#             print(df_gas_crops['CO2_levels'][i], df_gas_crops['N2O_levels'][i],df_gas_crops['CH4_levels'][i])
            df_gas_crops['CO2_levels'][i] = df_gas2['CO2_levels'][j]
            df_gas_crops['N2O_levels'][i] = df_gas2['N2O_levels'][j]
            df_gas_crops['CH4_levels'][i] = df_gas2['CH4_levels'][j]
#             year	CO2_levels	N2O_levels	CH4_levels
#             break
#     break
df_gas_crops
# Out:
#        Domain  Area Code         Area     Element  Item Code    Item  Year  \
# 0       Crops          2  Afghanistan  Production        515  Apples  1961
# 1       Crops          2  Afghanistan  Production        515  Apples  1962
# 2       Crops          2  Afghanistan  Production        515  Apples  1963
# 3       Crops          2  Afghanistan  Production        515  Apples  1964
# 4       Crops          2  Afghanistan  Production        515  Apples  1965
# ...       ...        ...          ...         ...        ...     ...   ...
# 154805  Crops        181     Zimbabwe  Production         15   Wheat  2015
# 154806  Crops        181     Zimbabwe  Production         15   Wheat  2016
# 154807  Crops        181     Zimbabwe  Production         15   Wheat  2017
# 154808  Crops        181     Zimbabwe  Production         15   Wheat  2018
# 154809  Crops        181     Zimbabwe  Production         15   Wheat  2019
#
# ...

# %%
df_gas_crops.to_csv("data/Gas_Crops_data.csv", index=False)
