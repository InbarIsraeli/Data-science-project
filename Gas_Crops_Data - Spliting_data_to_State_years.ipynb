# %% [markdown]
# # Search Topic
#
# In this notebook we will research about the diffrent kinds of Crops along the years 1984-2019 in global scale of growth, the amount of prodaction is by tonnes.
# we will check if the greenhouse gas levels had any affect on the crops.
#
# We will merge the amount of growth for each kind by year in a new data frame
#
# 1. compare between the kinds to see who was the most\least affected by the gas than others along the years
#     * which kind was the most prodacted althoug the gas levels went higher every year
#     * which kind was the least prodacted because the gas levels went higher every year
#
#
# 2. compare between the amount of production for a specific kind along the years to see if it was affected by the gas
#
# we can know all that from the gas levels and the amount of production

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
# import plotly.graph_objects as go
# import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import time 
import os
# %matplotlib inline

# %%
df_Gas_Crops_Data = pd.read_csv('./data/Gas_Crops_data.csv')
df_Gas_Crops_Data
# Out:
#        Domain  Area Code         Area     Element  Item Code    Item  Year  \
# 0       Crops          2  Afghanistan  Production        515  Apples  1961
# 1       Crops          2  Afghanistan  Production        515  Apples  1962
# 2       Crops          2  Afghanistan  Production        515  Apples  1963
# 3       Crops          2  Afghanistan  Production        515  Apples  1964
# 4       Crops          2  Afghanistan  Production        515  Apples  1965
# ...       ...        ...          ...         ...        ...     ...   ...
# 154805  Crops        181     Zimbabwe  Production         15   Wheat  2015
# 154806  Crops        181     Zimbabwe  Production         15   Wheat  2016
# 154807  Crops        181     Zimbabwe  Production         15   Wheat  2017
# 154808  Crops        181     Zimbabwe  Production         15   Wheat  2018
# 154809  Crops        181     Zimbabwe  Production         15   Wheat  2019
#
# ...

# %%
df_gas = pd.read_csv('./data/greenhouse gas.csv')
df_gas
# Out:
#     year  CO2_levels  N2O_levels  CH4_levels
# 0   1984      0.3443       303.9        1654
# 1   1985      0.3458       304.5        1666
# 2   1986      0.3472       305.3        1679
# 3   1987      0.3490       305.9        1691
# 4   1988      0.3514       306.7        1703
# 5   1989      0.3530       307.6        1714
# 6   1990      0.3542       308.6        1724
# 7   1991      0.3555       309.3        1735
# 8   1992      0.3562       309.9        1743
# 9   1993      0.3570       310.1        1746
# 10  1994      0.3586       310.7        1752
# 11  1995      0.3604       311.4        1759
# 12  1996      0.3621       312.0        1761
# 13  1997      0.3633       312.9        1765
# 14  1998      0.3660       313.7        1774
# 15  1999      0.3680       314.6        1782
# 16  2000      0.3695       315.7        1783
# 17  2001      0.3710       316.4        1782
# 18  2002      0.3729       317.1        1783
# 19  2003      0.3753       317.7        1787
# ...

# %%
df_gas_State = df_gas.copy()

df_gas_State["Afghanistan"]=0
df_gas_State["Colombia"]=0
df_gas_State["Denmark"]=0
df_gas_State["Israel"]=0
df_gas_State["Mexico"]=0
df_gas_State["Zimbabwe"]=0

df_gas_State
# Out:
#     year  CO2_levels  N2O_levels  CH4_levels  Afghanistan  Colombia  Denmark  \
# 0   1984      0.3443       303.9        1654            0         0        0
# 1   1985      0.3458       304.5        1666            0         0        0
# 2   1986      0.3472       305.3        1679            0         0        0
# 3   1987      0.3490       305.9        1691            0         0        0
# 4   1988      0.3514       306.7        1703            0         0        0
# 5   1989      0.3530       307.6        1714            0         0        0
# 6   1990      0.3542       308.6        1724            0         0        0
# 7   1991      0.3555       309.3        1735            0         0        0
# 8   1992      0.3562       309.9        1743            0         0        0
# 9   1993      0.3570       310.1        1746            0         0        0
# 10  1994      0.3586       310.7        1752            0         0        0
# ...

# %%
for i,valA in enumerate(df_Gas_Crops_Data['Year']):
#     print(i,valA)
#     print(df_Gas_Crops_Data['Area'][i])
    for j, valB in enumerate(df_gas_State['year']):
        if (valA == valB):
            if(df_Gas_Crops_Data['Area'][i]=='Afghanistan'):
                df_gas_State['Afghanistan'][j] = df_gas_State['Afghanistan'][j] + df_Gas_Crops_Data['Value'][i]
                
            if(df_Gas_Crops_Data['Area'][i]=='Israel'):
                    df_gas_State['Israel'][j] = df_gas_State['Israel'][j] + df_Gas_Crops_Data['Value'][i]
                
            if(df_Gas_Crops_Data['Area'][i]=='Zimbabwe'):
                    df_gas_State['Zimbabwe'][j] = df_gas_State['Zimbabwe'][j] + df_Gas_Crops_Data['Value'][i]
                    
            if(df_Gas_Crops_Data['Area'][i]=='Colombia'):
                    df_gas_State['Colombia'][j] = df_gas_State['Colombia'][j] + df_Gas_Crops_Data['Value'][i]
                    
            if(df_Gas_Crops_Data['Area'][i]=='Denmark'):
                    df_gas_State['Denmark'][j] = df_gas_State['Denmark'][j] + df_Gas_Crops_Data['Value'][i]
                    
            if(df_Gas_Crops_Data['Area'][i]=='Mexico'):
                    df_gas_State['Mexico'][j] = df_gas_State['Mexico'][j] + df_Gas_Crops_Data['Value'][i]
            
df_gas_State
# Out:
#     year  CO2_levels  N2O_levels  CH4_levels  Afghanistan  Colombia  Denmark  \
# 0   1984      0.3443       303.9        1654      4038094  31702277  3816302
# 1   1985      0.3458       304.5        1666      3847203  32634885  3309551
# 2   1986      0.3472       305.3        1679      3644301  32452784  3484081
# 3   1987      0.3490       305.9        1691      3918800  32949609  3384465
# 4   1988      0.3514       306.7        1703      3525670  34192174  3602763
# 5   1989      0.3530       307.6        1714      3343300  35744760  4669171
# 6   1990      0.3542       308.6        1724      3256041  37099214  5660752
# 7   1991      0.3555       309.3        1735      3256202  37023088  5343916
# 8   1992      0.3562       309.9        1743      2992146  38132527  5568295
# 9   1993      0.3570       310.1        1746      3455429  40199385  6336976
# 10  1994      0.3586       310.7        1752      3644102  41144948  5373347
# ...

# %%
df_gas_State.to_csv("data/State_years.csv", index=False)
