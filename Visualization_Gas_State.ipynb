# %% [markdown]
# # Visualization
#
# In this notebook we will visualize the effect of greenhouse gas affect on the crops along the years 1984-2019 in global growth, the amount of production is by tonnes.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
#import plotly.graph_objects as go
#import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import time 
import os
import matplotlib as mpl
import matplotlib.pyplot as plt      
import math
from collections import Counter
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
df_gas_State = pd.read_csv('./data/State_years.csv')
df_gas_State
# Out:
#     year  CO2_levels  N2O_levels  CH4_levels  Afghanistan  Colombia  Denmark  \
# 0   1984       344.3       303.9        1654      4038094  31702277  3816302
# 1   1985       345.8       304.5        1666      3847203  32634885  3309551
# 2   1986       347.2       305.3        1679      3644301  32452784  3484081
# 3   1987       349.0       305.9        1691      3918800  32949609  3384465
# 4   1988       351.4       306.7        1703      3525670  34192174  3602763
# 5   1989       353.0       307.6        1714      3343300  35744760  4669171
# 6   1990       354.2       308.6        1724      3256041  37099214  5660752
# 7   1991       355.5       309.3        1735      3256202  37023088  5343916
# 8   1992       356.2       309.9        1743      2992146  38132527  5568295
# 9   1993       357.0       310.1        1746      3455429  40199385  6336976
# 10  1994       358.6       310.7        1752      3644102  41144948  5373347
# ...

# %% [markdown]
# ### Bar plots of the state during the years

# %%
title="The effecr of Greenhous gas in Afghanistan"
ax1 = df_gas_State.groupby("year").sum()["Afghanistan"].plot.bar(title=title,color = 'pink',fontsize=18,figsize=(20,10))
ax1.title.set_size(25)
ax1.set_ylabel("Value in Tons",fontsize=18)
ax1.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
title="The effect of Greenhous gan in Colombia"
ax2 = df_gas_State.groupby("year").sum()["Colombia"].plot.bar(title=title,color = 'cyan',fontsize=18,figsize=(20,10))
ax2.title.set_size(25)
ax2.set_ylabel("Value in Tons",fontsize=18)
ax2.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
title="The effect of Greenhous gan in Denmark"
ax3 = df_gas_State.groupby("year").sum()["Denmark"].plot.bar(title=title,color = 'lightcoral',fontsize=18,figsize=(20,10))
ax3.title.set_size(25)
ax3.set_ylabel("Value in Tons",fontsize=18)
ax3.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
title="The effect of Greenhous gan in Israel"
ax4 = df_gas_State.groupby("year").sum()["Israel"].plot.bar(title=title,color = 'lightgreen',fontsize=18,figsize=(20,10))
ax4.title.set_size(25)
ax4.set_ylabel("Value in Tons",fontsize=18)
ax4.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
title="The effect of Greenhous gan in Mexico"
ax5 = df_gas_State.groupby("year").sum()["Mexico"].plot.bar(title=title,color = 'red',fontsize=18,figsize=(20,10))
ax5.title.set_size(25)
ax5.set_ylabel("Value in Tons",fontsize=18)
ax5.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
title="The effect of Greenhous gan in Zimbabwe"
ax6 = df_gas_State.groupby("year").sum()["Zimbabwe"].plot.bar(title=title,color = 'pink',fontsize=18,figsize=(20,10))
ax6.title.set_size(25)
ax6.set_ylabel("Value in Tons",fontsize=18)
ax6.set_xlabel("year",fontsize=18)
# Out:
# Text(0.5, 0, 'year')

# %%
df_gas_State.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         36 non-null     int64
#  1   CO2_levels   36 non-null     float64
#  2   N2O_levels   36 non-null     float64
#  3   CH4_levels   36 non-null     int64
#  4   Afghanistan  36 non-null     int64
#  5   Colombia     36 non-null     int64
#  6   Denmark      36 non-null     int64
#  7   Israel       36 non-null     int64
#  8   Mexico       36 non-null     int64
#  9   Zimbabwe     36 non-null     int64
# dtypes: float64(2), int64(8)
# memory usage: 2.9 KB

# %%
df_gas_State.describe()
# Out:
#               year  CO2_levels  N2O_levels   CH4_levels   Afghanistan  \
# count    36.000000   36.000000   36.000000    36.000000  3.600000e+01
# mean   2001.500000  374.091667  317.025000  1776.027778  4.951469e+06
# std      10.535654   19.651701    8.344318    55.825486  1.689615e+06
# min    1984.000000  344.300000  303.900000  1654.000000  2.670122e+06
# 25%    1992.750000  356.800000  310.050000  1745.250000  3.644251e+06
# 50%    2001.500000  371.950000  316.750000  1783.000000  4.209602e+06
# 75%    2010.250000  389.475000  323.550000  1810.250000  6.469874e+06
# max    2019.000000  410.500000  332.000000  1877.000000  8.673262e+06
#
#            Colombia       Denmark        Israel        Mexico      Zimbabwe
# count  3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01
# mean   4.270849e+07  6.031420e+06  2.194416e+06  8.822295e+07  5.344010e+06
# std    5.707170e+06  1.233602e+06  1.617266e+05  1.415018e+07  1.188515e+06
# ...

# %%
gas_series = df_gas_State['Afghanistan'].value_counts()
gas_values = list(gas_series.values)
gas_index = ['CO2_levels', 'N2O_levels', 'CH4_levels']
gas_colors = ['#E74C3C', '#F1C40F', '#27AE60']

# status_series = animals_df['Status'].value_counts()
# status_values = status_series.values.tolist()
# status_index = ['Safe animals', 'Endangered']
# status_colors = ['#27AE60', '#E74C3C']

# fig, axs = plt.subplots(1,2, figsize=(16,5))

# axs[0].pie(gas_values, labels=gas_index, autopct='%1.1f%%', shadow=True, startangle=90,
#            explode=(0.05, 0.05, 0.05), radius=1.5, colors=gas_colors, textprops={'fontsize':15})
# # axs[1].pie(status_values, labels=status_index, autopct='%1.1f%%', shadow=True,
# #            startangle=90, explode=(0.05, 0.05), radius=1.5, colors=status_colors, textprops={'fontsize':15})

# fig.suptitle('Afghanistan')
print(gas_index)
# Out:
# ['CO2_levels', 'N2O_levels', 'CH4_levels']

# %%
#CO2_levels	N2O_levels	CH4_levels#in 2019 the gas levels where:
#410.5	332.0	1877
sum=410.5+332+1877
x=410.5/sum
y=332/sum
z=1877/sum
print(x,y,z)

plt.axis("equal")
lab=['CO2_levels', 'N2O_levels','CH4_levels']
ratios=[x,y,z]
plt.pie(ratios,data=df_gas_State,labels=lab,radius=2,autopct='%1.1f%%',explode = [0.1, 0, 0],startangle=(-180 * ratios[0]))
plt.show()
# Out:
# 0.15670929566711203 0.12674174460774956 0.7165489597251384
